# %%
import glob
import random
import numpy as np

from keyrover import *

# %%
files = glob.glob("*.jpg")
files
# Out:
# ['2.jpg', '1.jpg', '0.jpg']

# %%
img = Image.open(random.choice(files))
imshow(img)

# %%
imhist(img)

# %%
_, axes = gridplot(len(files))    

for i, ax in enumerate(axes):
    axes[i].axis("off")
    if i < len(files):
        imhist(files[i], axes[i])

# %%
# Average Histogram

images = np.array([Image.open(path) for path in files])
imhist(images)
