# %%
from keyrover.images import KeyboardImage
from keyrover.images.key_mask import KeyMaskImage
from keyrover.images.binary_key_mask import KeyBinaryMaskImage
from keyrover.images.texcoord import TexcoordImage

# %%
image = KeyboardImage("v4/keyboard_2455_1.jpg")
image.show()

# %%
mask = KeyBinaryMaskImage("v4/keyboard_2455_1.png")
mask.show()

# %%
mask = KeyMaskImage("v4/keyboard_2455_1.png")
mask.show()

mask.show_crops()

# %%
texcoords = TexcoordImage("v4/keyboard_2455_1.png")
texcoords.show()

texcoords.texcoords
# Out:
# {'lctrl': (11.0, 25.0),
#  'windows': (25.0, 27.0),
#  'lalt': (43.0, 27.0),
#  'lshift': (17.0, 64.0),
#  'Z': (35.0, 67.0),
#  'caps': (15.0, 106.0),
#  'X': (49.0, 66.0),
#  'C': (62.0, 67.0),
#  'A': (28.0, 108.0),
#  'V': (76.0, 67.0),
#  'S': (42.0, 109.0),
#  'space': (80.0, 32.0),
#  'B': (90.0, 67.0),
#  'D': (55.0, 108.0),
#  'N': (104.0, 67.0),
#  'Q': (24.0, 149.0),
#  'F': (69.0, 108.0),
#  'ralt': (141.0, 27.0),
#  'M': (118.0, 67.0),
#  'W': (38.0, 149.0),
#  'G': (83.0, 109.0),
#  'E': (52.0, 149.0),
#  'fn': (159.0, 28.0),
#  '<': (132.0, 67.0),
#  'H': (97.0, 108.0),
#  'R': (65.0, 149.0),
#  'J': (111.0, 108.0),
#  '>': (146.0, 67.0),
#  'T': (79.0, 149.0),
#  '2': (32.0, 189.0),
#  'K': (125.0, 109.0),
#  '3': (46.0, 188.0),
#  'Y': (93.0, 149.0),
#  '?': (159.0, 67.0),
#  '4': (60.0, 189.0),
#  'L': (139.0, 109.0),
#  'U': (107.0, 150.0),
#  '5': (74.0, 189.0),
#  'I': (121.0, 149.0),
#  '6': (88.0, 189.0),
#  ';': (153.0, 109.0),
#  'f1': (33.0, 232.0),
# ...
